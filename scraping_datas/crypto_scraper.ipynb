# %%
from cryptocmd import CmcScraper

# %%
# initialise scraper without time interval
scraper = CmcScraper("BTC")

# get raw data as list of list
headers, data = scraper.get_data()

# get data in a json format
btc_json_data = scraper.get_data("json")

# export the data as csv file, you can also pass optional `name` parameter
scraper.export("csv", name="btc_all_time")

# Pandas dataFrame for the same data
df = scraper.get_dataframe()

# %%
# reverse the order of the data
df = df.iloc[::-1]

# remove the data in year 2013/2021
df = df[df.Date.dt.year != 2013]
df = df[df.Date.dt.year != 2021]

# export the pd dataframe to csv file
df.to_csv('btc_processed.csv', index=False)
df
# Out:
#            Date          Open          High           Low         Close  \
# 2622 2014-01-01    754.969971    775.349976    754.969971    771.400024
# 2621 2014-01-02    773.440002    820.309998    767.210022    802.390015
# 2620 2014-01-03    802.849976    834.150024    789.119995    818.719971
# 2619 2014-01-04    823.270020    859.510010    801.669983    859.510010
# 2618 2014-01-05    858.549988    952.400024    854.520020    933.530029
# ...         ...           ...           ...           ...           ...
# 70   2020-12-27  26439.373289  28288.840022  25922.769765  26272.294567
# 69   2020-12-28  26280.821415  27389.112064  26207.639931  27084.807886
# 68   2020-12-29  27081.809729  27370.720084  25987.298075  27362.436557
# 67   2020-12-30  27360.089709  28937.740004  27360.089709  28840.953420
# 66   2020-12-31  28841.573758  29244.876688  28201.991994  29001.719822
#
#             Volume    Market Cap
# 2622  2.248940e+07  9.403308e+09
# 2621  3.848950e+07  9.781074e+09
# ...
