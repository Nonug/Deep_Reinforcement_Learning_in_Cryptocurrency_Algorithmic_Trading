# %%
# %cd ./tdqn_final
# Out:
# /home/johnny/shared/COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main/tdqn_final

# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()
import testStrategy as testStrategy

# %%
classicalStrats = {
    'Buy and Hold' : 'b&h',
    'Sell and Hold' : 's&h',
    'Trend Following Moving Averages' : 'tfma'
}
AI = ['DQN', 'LSTM', 'ConvDuelingDQN']

# %% [markdown]
# ## DQN with cross-validation
# ### mode = train, test, backtest
#
# - Note that the train results may not be identical to the one appeared in the report, as no cross-validation is done here
#
# - select the mode to show the corrisponding results
#
#
# starting capital: $100000
#
#
# Training period: 2014-2017
#
# Validation period: 2017-2019
#
# Testing period: 2019-2021
#
# Backtesting perioid: 2014-2021

# %%
# mode = train, test, backtest
testStrategy.testAI("DQN", mode = 'test')
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -98717  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 110.67%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.261  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.408  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 105.16%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 93 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  92.86%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -16.431  │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ## ConvDuelingDQN with cross-validation, dropout layer and optimized

# %%
testStrategy.testAI("ConvDuelingDQN", name = "optimized", mode = 'test')
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  714784  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  89.65%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  57.35%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.561   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.891   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  62.09%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 260 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -1.073  │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ## LSTM with cross-validation, normalized layers

# %%
testStrategy.testAI("LSTM", mode = 'test')
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -98717  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 110.67%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.261  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.408  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 105.16%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 93 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  93.33%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -16.431  │
# ╘═══════════════════════════╧══════════╛
