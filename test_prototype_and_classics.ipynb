# %%
# %cd ./tdqn_prototype
# Out:
# /home/johnny/shared/COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main/tdqn_prototype

# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()
import testStrategy as testStrategy

# %%
cryptocurrency = "Bitcoin"
simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# Number of empty elements:
# Open     0
# High     0
# Low      0
# Close    0
# s2f      0
# dtype: int64
# Number of duplicates:
# 0

# %%
classicalStrats = {
    'Buy and Hold' : 'b&h',
    'Sell and Hold' : 's&h',
    'Trend Following Moving Averages' : 'tfma'
}
AI = ['DQN', 'LSTM', 'ConvDuelingDQN']

# %% [markdown]
# ## Showing the performance of non-AI strategies
# starting capital: $100000

# %%
strat = 'Buy and Hold'
testStrategy.train(strat)
# Out:
# No training is required as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# No training results are available as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   B&H    │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  364249  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  31.41%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  61.81%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.652   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.855   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.46%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# ...

# %% [markdown]
# ## DQN performance from our interim prototype (Best agent)
# mode = train, test, backtest
#
# select the mode to show the corrisponding results
#
#
# starting capital: $100000
#
#
# Training period: 2014-2017
#
# Validation period: 2017-2019
#
# Testing period: 2019-2021
#
# Backtesting perioid: 2014-2021

# %%
# mode = train, test, backtest
testStrategy.testAI("DQN", mode = 'backtest')
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 76757560 │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  37.75%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  59.56%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.393   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  2.023   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  76.01%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 111 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  51.27%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.998   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.904   │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ### DQN testing trades animated
# ![DQN testing trades animated](btc_tdqn_dqn_test_Rendering_prototype.gif "Title")
