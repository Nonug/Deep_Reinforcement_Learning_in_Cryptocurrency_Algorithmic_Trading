# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()

# %%
# strategy in {
#     'Buy and Hold',
#     'Sell and Hold',
#     'Trend Following Moving Averages',
#     'Mean Reversion Moving Averages',
#     'TDQN'
# }
# cryptocurrency in {'Bitcoin', 'Ethereum'}

# %%
cryptocurrency = "Bitcoin"
simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# Number of empty elements:
# Open     0
# High     0
# Low      0
# Close    0
# s2f      0
# dtype: int64
# Number of duplicates:
# 0

# %%
percentageCosts = [0, 0.1, 0.2]
transactionCosts = percentageCosts[1]/100
stateLength = 30
AI_TRAINING_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    # Parameters related to the DQN algorithm
    'stateLength': stateLength,
    'numberOfEpisodes': 50,
    'gamma': 0.4,
    'learningRate': 0.0001,
    'targetNetworkUpdate': 1000,
    'learningUpdatePeriod': 1,
    'capacity': 100000,
    'batchSize': 32,
    'experiencesRequired': 1000,
    'epsilonStart': 1.0,
    'epsilonEnd': 0.01,
    'epsilonDecay': 10000,
    'name': 'training',
}

NON_AI_TRAINING_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    'name': 'training',
}

VALIDATION_BACKTEST_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'validation_backtest'
}

VALIDATION_PARAM = {
    'startingDate': '2017-01-01',
    'endingDate': '2019-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'validation_test'
}

BACKTEST_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2019-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'backtest'
}

TEST_PARAM = {
    'startingDate': '2019-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'test'
}

ETH_TEST_PARAM = {
    'startingDate': '2019-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'test'
}

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['name'] = 'btc_tdqn_training'
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
print()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [14:15<00:00, 17.10s/it]
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 31105979 │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  93.14%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  46.02%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  3.100   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  5.684   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  17.92%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 51 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  71.64%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  3.341   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  1.465   │
# ╘═══════════════════════════╧══════════╛

# %%
# May be unnecssary because it should be the same as training results
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_BACKTEST_PARAM['name'] = 'btc_tdqn_validation_backtest'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_BACKTEST_PARAM)
# print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_tdqn_validation'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -28556  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  19.17%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  70.78%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.205   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.251   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  89.73%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 378 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  46.67%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.090   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.865  │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_backtest'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 17712392 │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  49.49%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  59.77%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.493   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  2.172   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.47%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  62.14%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  2.403   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.628   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_test'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤═════════╕
# │   Performance Indicator   │  TDQN   │
# ╞═══════════════════════════╪═════════╡
# │    Profit & Loss (P&L)    │ 164370  │
# ├───────────────────────────┼─────────┤
# │     Annualized Return     │ 53.99%  │
# ├───────────────────────────┼─────────┤
# │   Annualized Volatility   │ 52.59%  │
# ├───────────────────────────┼─────────┤
# │       Sharpe Ratio        │  0.899  │
# ├───────────────────────────┼─────────┤
# │       Sortino Ratio       │  1.223  │
# ├───────────────────────────┼─────────┤
# │     Maximum Drawdown      │ 40.08%  │
# ├───────────────────────────┼─────────┤
# │ Maximum Drawdown Duration │ 47 days │
# ├───────────────────────────┼─────────┤
# │       Profitability       │ 44.93%  │
# ├───────────────────────────┼─────────┤
# │ Ratio Average Profit/Loss │  1.899  │
# ├───────────────────────────┼─────────┤
# │         Skewness          │  0.409  │
# ╘═══════════════════════════╧═════════╛

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# TEST_PARAM['name'] = 'eth_tdqn_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_b&h_training'
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()
# Out:
# No training is required as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# No training results are available as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   B&H    │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  20329   │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  21.47%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  52.63%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.346   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.427   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  78.61%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 346 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.133  │
# ╘═══════════════════════════╧══════════╛

# %%
# strategy = "Buy and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_BACKTEST_PARAM['name'] = 'btc_b&h_validation_backtest'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_BACKTEST_PARAM)
# print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_b&h_validation'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   B&H    │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  285459  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  76.00%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  71.93%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.004   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.442   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.47%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.356   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_b&h_backtest'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   B&H    │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  364249  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  31.41%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  61.81%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.652   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.855   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.46%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.168   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_b&h_test'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Buy and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_b&h_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_s&h_training'
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
# strategy = "Sell and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_BACKTEST_PARAM['name'] = 'btc_s&h_validation_backtest'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_BACKTEST_PARAM)
# print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_s&h_validation'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_s&h_backtest'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_s&h_test'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Sell and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_s&h_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_tfma_training'
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
# strategy = "Trend Following Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_BACKTEST_PARAM['name'] = "btc_tfma_validation_backtest"
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_BACKTEST_PARAM)
# print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = "btc_tfma_validation"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = "btc_tfma_backtest"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = "btc_tfma_test"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Trend Following Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = "eth_tfma_test"
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_mrma_training'
simulator.nonAitrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_BACKTEST_PARAM['name'] = "btc_mrma_validation_backtest"
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_BACKTEST_PARAM)
# print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = "btc_mrma_validation"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = "btc_mrma_backtest"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = "btc_mrma_test"
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = "eth_mrma_test"
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()
