# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()
import testStrategy

# %%
cryptocurrency = "Bitcoin"
simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# Number of empty elements:
# Open     0
# High     0
# Low      0
# Close    0
# s2f      0
# dtype: int64
# Number of duplicates:
# 0

# %%
testStrategy.testAI("DQN")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  703335  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  88.13%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  54.99%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.592   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.883   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  60.01%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 251 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.918  │
# ╘═══════════════════════════╧══════════╛

# %%
testStrategy.testAI("ConvDuelingDQN")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  718197  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  89.78%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  57.84%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.551   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.929   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  63.54%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 261 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.405  │
# ╘═══════════════════════════╧══════════╛

# %%
# strategy = "Buy and Hold"
# trainCryptocurrency = "Bitcoin"
# NON_AI_TRAINING_PARAM['name'] = 'btc_b&h_training'
# NON_AI_TRAINING_PARAM['network'] = ''
# simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
# print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'DQN'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_DQN_training'
VALIDATION_PARAM['network'] = 'DQN'
VALIDATION_PARAM['name'] = 'btc_tdqn_DQN_validation'
# WithCrossValidation
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM, VALIDATION_PARAM)
print()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# C:\Users\Victor\Documents\school\yr 2 sem 2\COMP3359 AI applications\COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main\CONT action space\tdqn_cont3\tradingEnv.py:383: RuntimeWarning: invalid value encountered in double_scalars
#   newAssetPct = newHoldings / newMoney
# 100%|██████████| 1/1 [00:16<00:00, 16.22s/it]
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  20396   │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  21.68%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  53.01%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.348   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.429   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  78.87%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 346 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.132  │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_DQN_test'
TEST_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, TEST_PARAM)
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ae6972d3c284> in <module>
#       4 TEST_PARAM['name'] = 'btc_tdqn_DQN_test'
#       5 TEST_PARAM['network'] = 'DQN'
# ----> 6 simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, TEST_PARAM)
#       7 print()
#
# ~\Documents\school\yr 2 sem 2\COMP3359 AI applications\COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main\CONT action space\tdqn_cont3\tradingSimulator.py in test(self, strategyName, trainCryptocurrencyName, testCryptocurrencyName, TRAIN_PARAM, TEST_PARAM, rendering, showPerformance)
#     359         testingEnv = TradingEnv(testCryptocurrency, startingDate, endingDate, money, name, stateLength,
#     360                                 transactionCosts)
# --> 361         testingEnv = tradingStrategy.testing(trainingEnv, testingEnv, name, rendering=rendering,
#     362                                             showPerformance=showPerformance)
#     363
#
# ~\Documents\school\yr 2 sem 2\COMP3359 AI applications\COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main\CONT action space\tdqn_cont3\TDQN.py in testing(self, trainingEnv, testingEnv, name, rendering, showPerformance)
#     749         # If required, show the rendering of the trading environment
#     750         if rendering:
# --> 751             testingEnv.render()
#     752             self.plotQValues(QValues, name)
#     753
#
# ~\Documents\school\yr 2 sem 2\COMP3359 AI applications\COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main\CONT action space\tdqn_cont3\tradingEnv.py in render(self)
#     507
#     508         ani = animation.FuncAnimation(self.fig, self.animate, frames=len(self.data)-1, interval=200, repeat_delay=5000)
# --> 509         ani.save(os.path.join('Figures', self.name+'_Rendering.gif'), writer=writergif)
#     510
#     511     def render_old(self):
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1139                 for anim, d in zip(all_anim, data):
#    1140                     # TODO: See if turning off blit is really necessary
# -> 1141                     anim._draw_next_frame(d, blit=False)
#    1142                     if progress_callback is not None:
#    1143                         progress_callback(frame_number, total_frames)
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in _draw_next_frame(self, framedata, blit)
#    1175         self._pre_draw(framedata, blit)
#    1176         self._draw_frame(framedata)
# -> 1177         self._post_draw(framedata, blit)
#    1178
#    1179     def _init_draw(self):
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in _post_draw(self, framedata, blit)
#    1200             self._blit_draw(self._drawn_artists)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#    1204     # The rest of the code in this class is to facilitate easy blitting
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\legend.py in draw(self, renderer)
#     604         # update the location and size of the legend. This needs to
#     605         # be done in any case to clip the figure right.
# --> 606         bbox = self._legend_box.get_window_extent(renderer)
#     607         self.legendPatch.set_bounds(bbox.x0, bbox.y0, bbox.width, bbox.height)
#     608         self.legendPatch.set_mutation_scale(fontsize)
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\offsetbox.py in get_window_extent(self, renderer)
#     345         """Return the bounding box (`.Bbox`) in display space."""
#     346         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
# --> 347         px, py = self.get_offset(w, h, xd, yd, renderer)
#     348         return mtransforms.Bbox.from_bounds(px - xd, py - yd, w, h)
#     349
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\offsetbox.py in get_offset(self, width, height, xdescent, ydescent, renderer)
#     284
#     285         """
# --> 286         return (self._offset(width, height, xdescent, ydescent, renderer)
#     287                 if callable(self._offset)
#     288                 else self._offset)
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\legend.py in _findoffset(self, width, height, xdescent, ydescent, renderer)
#     573
#     574         if self._loc == 0:  # "best".
# --> 575             x, y = self._find_best_position(width, height, renderer)
#     576         elif self._loc in Legend.codes.values():  # Fixed location.
#     577             bbox = Bbox.from_bounds(0, 0, width, height)
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\legend.py in _find_best_position(self, width, height, renderer, consider)
#    1031         start_time = time.perf_counter()
#    1032
# -> 1033         bboxes, lines, offsets = self._auto_legend_data()
#    1034
#    1035         bbox = Bbox.from_bounds(0, 0, width, height)
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\legend.py in _auto_legend_data(self)
#     834         assert self.isaxes  # always holds, as this is only called internally
#     835         ax = self.parent
# --> 836         lines = [line.get_transform().transform_path(line.get_path())
#     837                  for line in ax.lines]
#     838         bboxes = [patch.get_bbox().transformed(patch.get_data_transform())
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\legend.py in <listcomp>(.0)
#     834         assert self.isaxes  # always holds, as this is only called internally
#     835         ax = self.parent
# --> 836         lines = [line.get_transform().transform_path(line.get_path())
#     837                  for line in ax.lines]
#     838         bboxes = [patch.get_bbox().transformed(patch.get_data_transform())
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in transform_path(self, path)
#    1525         that began as line segments.
#    1526         """
# -> 1527         return self.transform_path_affine(self.transform_path_non_affine(path))
#    1528
#    1529     def transform_path_affine(self, path):
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in transform_path_affine(self, path)
#    1535         ``transform_path_affine(transform_path_non_affine(values))``.
#    1536         """
# -> 1537         return self.get_affine().transform_path_affine(path)
#    1538
#    1539     def transform_path_non_affine(self, path):
#
# c:\users\victor\appdata\local\programs\python\python38\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2369             return self._b.get_affine()
#    2370         else:
# -> 2371             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2372                                    self._a.get_affine().get_matrix()))
#    2373
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_DQN_backtest'
BACKTEST_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 3506443  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  30.65%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  61.11%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.887   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.144   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.47%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.143  │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'LSTM'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_LSTM_training'
VALIDATION_PARAM['network'] = 'LSTM'
VALIDATION_PARAM['name'] = 'btc_tdqn_LSTM_validation'
simulator.aiTrainWithCrossValidation(strategy, trainCryptocurrency, AI_TRAINING_PARAM, VALIDATION_PARAM)
print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_LSTM_test'
TEST_PARAM['network'] = 'LSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, TEST_PARAM)
print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_LSTM_backtest'
BACKTEST_PARAM['network'] = 'LSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, BACKTEST_PARAM)
print()

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_DQN_test'
# ETH_TEST_PARAM['network'] = 'DQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, ETH_TEST_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# NON_AI_TRAINING_PARAM['name'] = 'btc_mrma_training'
# simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# BACKTEST_PARAM['name'] = 'btc_mrma_backtest'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, NON_AI_TRAINING_PARAM, BACKTEST_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# TEST_PARAM['name'] = 'btc_mrma_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, NON_AI_TRAINING_PARAM, TEST_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_mrma_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, NON_AI_TRAINING_PARAM, ETH_TEST_PARAM)
# print()
