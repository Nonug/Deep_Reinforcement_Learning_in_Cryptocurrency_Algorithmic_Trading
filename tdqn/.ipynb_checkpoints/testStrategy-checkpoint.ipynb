# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()
import testStrategy

# %%
# cryptocurrency = "Bitcoin"
# simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-2-5990d9136ea8> in <module>
#       1 cryptocurrency = "Bitcoin"
# ----> 2 simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
#
# ~/COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading/tdqn/tradingSimulator.py in exploratoryDataAnalysis(self, cryptocurrencyName, startingDate, endingDate)
#      51         analyser = ExploratoryDataAnalysis(tradingEnv.data, cryptocurrency)
#      52         analyser.plotTimeSeries()
# ---> 53         analyser.plot_daily_returns()
#      54         analyser.bollingerBandStrategy()
#      55         analyser.plot_scarcity()
#
# ~/COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading/tdqn/exploratoryDataAnalysis.py in plot_daily_returns(self)
#      58         def plot_daily_returns(self):
#      59                 daily_returns = (self.timeSeries / self.timeSeries.shift(1)) - 1
# ---> 60                 daily_returns.iloc[0,:] = 0
#      61                 ax = daily_returns.plot(title=self.symbol+" Daily returns", fontsize=12)
#      62                 ax.set_xlabel("Date")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     202         else:
#     203             key = com.apply_if_callable(key, self.obj)
# --> 204         indexer = self._get_setitem_indexer(key)
#     205         self._setitem_with_indexer(indexer, value)
#     206
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     189         axis = self.axis or 0
#     190         try:
# --> 191             return self._convert_to_indexer(key, axis=axis, is_setter=True)
#     192         except TypeError as e:
#     193
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    2173
#    2174         try:
# -> 2175             self._validate_key(obj, axis)
#    2176             return obj
#    2177         except ValueError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    2016             # a tuple should already have been caught by this point
#    2017             # so don't treat a tuple as a valid indexer
# -> 2018             raise IndexingError("Too many indexers")
#    2019         elif is_list_like_indexer(key):
#    2020             arr = np.array(key)
#
# IndexingError: Too many indexers

# %%
testStrategy.testAI("DQN")

# %%
testStrategy.testAI("LSTM")

# %%
testStrategy.testAI("ConvDuelingDQN")
