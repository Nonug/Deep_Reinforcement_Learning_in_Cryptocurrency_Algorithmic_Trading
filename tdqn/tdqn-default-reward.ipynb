# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()

# %%
# strategy in {
#     'Buy and Hold',
#     'Sell and Hold',
#     'Trend Following Moving Averages',
#     'Mean Reversion Moving Averages',
#     'TDQN'
# }
# cryptocurrency in {'Bitcoin', 'Ethereum'}
# network in {"DQN", "LSTM", "BiLSTM", "DuelingDQN", "ConvDuelingDQN"}

# %%
cryptocurrency = "Bitcoin"
simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# Number of empty elements:
# Open     0
# High     0
# Low      0
# Close    0
# s2f      0
# dtype: int64
# Number of duplicates:
# 0

# %%
percentageCosts = [0, 0.1, 0.2]
transactionCosts = percentageCosts[1]/100
stateLength = 30
AI_TRAINING_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    # Parameters related to the DQN algorithm
    'stateLength': stateLength,
    'numberOfEpisodes': 50,
    'gamma': 0.4,
    'learningRate': 0.0001,
    'targetNetworkUpdate': 1000,
    'learningUpdatePeriod': 1,
    'capacity': 100000,
    'batchSize': 32,
    'experiencesRequired': 1000,
    'epsilonStart': 1.0,
    'epsilonEnd': 0.01,
    'epsilonDecay': 10000,
    'name': 'training',
    'network': 'DQN',
    'rewardMode': 'default',
}

NON_AI_TRAINING_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    'name': 'training',
    'network': ''
}

VALIDATION_BACKTEST_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2017-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'validation_backtest',
    'network': '',
}

VALIDATION_PARAM = {
    'startingDate': '2017-01-01',
    'endingDate': '2019-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'validation_test',
    'network': '',
}

BACKTEST_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2019-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'backtest',
    'network': '',
}

TEST_PARAM = {
    'startingDate': '2019-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'test',
    'network': '',
}

ETH_TEST_PARAM = {
    'startingDate': '2019-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'test',
    'network': '',
}

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'LSTM'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_lstm_training'
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
print()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [11:06<00:00, 13.33s/it]
# ╒═══════════════════════════╤═════════╕
# │   Performance Indicator   │  TDQN   │
# ╞═══════════════════════════╪═════════╡
# │    Profit & Loss (P&L)    │ 2752305 │
# ├───────────────────────────┼─────────┤
# │     Annualized Return     │ 69.26%  │
# ├───────────────────────────┼─────────┤
# │   Annualized Volatility   │ 48.28%  │
# ├───────────────────────────┼─────────┤
# │       Sharpe Ratio        │  1.833  │
# ├───────────────────────────┼─────────┤
# │       Sortino Ratio       │  3.024  │
# ├───────────────────────────┼─────────┤
# │     Maximum Drawdown      │ 19.94%  │
# ├───────────────────────────┼─────────┤
# │ Maximum Drawdown Duration │ 60 days │
# ├───────────────────────────┼─────────┤
# │       Profitability       │ 48.85%  │
# ├───────────────────────────┼─────────┤
# │ Ratio Average Profit/Loss │  2.580  │
# ├───────────────────────────┼─────────┤
# │         Skewness          │  1.336  │
# ╘═══════════════════════════╧═════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['network'] = 'LSTM'
VALIDATION_PARAM['name'] = 'btc_tdqn_lstm_validation'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  108425  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  56.78%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  70.72%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.710   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.995   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  82.69%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 111 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  46.48%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.303   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.277   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_lstm_backtest'
BACKTEST_PARAM['network'] = 'LSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  854675  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  35.50%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  60.47%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.814   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.166   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  78.03%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 111 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  43.60%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.606   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.564   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_lstm_test'
TEST_PARAM['network'] = 'LSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  119559  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  48.90%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  55.45%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.757   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.134   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  55.83%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 193 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  43.43%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.619   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  1.873   │
# ╘═══════════════════════════╧══════════╛

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_lstm_test'
# ETH_TEST_PARAM['network'] = 'LSTM'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'DQN'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_dqn_training'
AI_TRAINING_PARAM['network'] = 'DQN'
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
print()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Training progression (hardware selected => cpu):
#  67%|██████▋   | 2/3 [04:28<02:12, 132.15s/it]

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_tdqn_dqn_validation'
VALIDATION_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_dqn_backtest'
BACKTEST_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_dqn_test'
TEST_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_dqn_test'
# ETH_TEST_PARAM['network'] = 'DQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'BiLSTM'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_bilstm_training'
AI_TRAINING_PARAM['network'] = 'BiLSTM'
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
print()
# Out:
# reward mode is default
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [13:24<00:00, 16.10s/it]
# ╒═══════════════════════════╤═════════╕
# │   Performance Indicator   │  TDQN   │
# ╞═══════════════════════════╪═════════╡
# │    Profit & Loss (P&L)    │ 1873562 │
# ├───────────────────────────┼─────────┤
# │     Annualized Return     │ 64.89%  │
# ├───────────────────────────┼─────────┤
# │   Annualized Volatility   │ 48.46%  │
# ├───────────────────────────┼─────────┤
# │       Sharpe Ratio        │  1.653  │
# ├───────────────────────────┼─────────┤
# │       Sortino Ratio       │  2.760  │
# ├───────────────────────────┼─────────┤
# │     Maximum Drawdown      │ 31.72%  │
# ├───────────────────────────┼─────────┤
# │ Maximum Drawdown Duration │ 72 days │
# ├───────────────────────────┼─────────┤
# │       Profitability       │ 48.20%  │
# ├───────────────────────────┼─────────┤
# │ Ratio Average Profit/Loss │  2.217  │
# ├───────────────────────────┼─────────┤
# │         Skewness          │  1.380  │
# ╘═══════════════════════════╧═════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_tdqn_bilstm_validation'
VALIDATION_PARAM['network'] = 'BiLSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  90340   │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  53.61%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  70.38%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.665   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.940   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.25%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 111 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  44.44%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.396   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.299   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_bilstm_backtest'
BACKTEST_PARAM['network'] = 'BiLSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  708076  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  34.41%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  60.09%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.778   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.094   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  80.11%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 111 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  41.56%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.682   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.488   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_bilstm_test'
TEST_PARAM['network'] = 'BiLSTM'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  26858   │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  29.51%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  55.86%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.418   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.593   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  55.51%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 198 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  45.28%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.307   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  1.688   │
# ╘═══════════════════════════╧══════════╛

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_bilstm_test'
# ETH_TEST_PARAM['network'] = 'BiLSTM'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'DuelingDQN'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_dueling_dqn_training'
simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
print()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [10:29<00:00, 12.58s/it]
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 29606529 │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  92.91%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  47.19%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  3.010   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  5.277   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  7.76%   │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 25 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  65.05%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  3.880   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  1.390   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_tdqn_duelingDQN_validation'
VALIDATION_PARAM['network'] = 'DuelingDQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -35909  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  14.81%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  71.58%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.153   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.187   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  90.89%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 375 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  46.88%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.080   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.608  │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_duelingDQN_backtest'
BACKTEST_PARAM['network'] = 'DuelingDQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ 1384599  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  38.17%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  60.86%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.915   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.230   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  74.99%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 343 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  52.11%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.236   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  0.297   │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_duelingDQN_test'
TEST_PARAM['network'] = 'DuelingDQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -32417  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  3.37%   │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  56.96%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.041   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.058   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  66.98%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 259 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  44.68%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.117   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  1.231   │
# ╘═══════════════════════════╧══════════╛

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_duelingDQN_test'
# ETH_TEST_PARAM['network'] = 'DuelingDQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# AI_TRAINING_PARAM['network'] = 'ConvDuelingDQN'
# AI_TRAINING_PARAM['name'] = 'btc_tdqn_conv_dueling_dqn_training'
# simulator.aiTrain(strategy, trainCryptocurrency, AI_TRAINING_PARAM)
# print()

# %%
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# VALIDATION_PARAM['name'] = 'btc_tdqn_convDuelingDQN_validation'
# VALIDATION_PARAM['network'] = 'ConvDuelingDQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
# print()

# %%
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# BACKTEST_PARAM['name'] = 'btc_tdqn_convDuelingDQN_backtest'
# BACKTEST_PARAM['network'] = 'ConvDuelingDQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
# print()

# %%
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# TEST_PARAM['name'] = 'btc_tdqn_convDuelingDQN_test'
# TEST_PARAM['network'] = 'ConvDuelingDQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
# print()

# %%
# Haven't scraped eth s2f
# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_tdqn_convDuelingDQN_test'
# ETH_TEST_PARAM['network'] = 'ConvDuelingDQN'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_b&h_training'
NON_AI_TRAINING_PARAM['network'] = ''
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_b&h_validation'
VALIDATION_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_b&h_backtest'
BACKTEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Buy and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_b&h_test'
TEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Buy and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_b&h_test'
# ETH_TEST_PARAM['network'] = ''
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_s&h_training'
NON_AI_TRAINING_PARAM['network'] = ''
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = 'btc_s&h_validation'
VALIDATION_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_s&h_backtest'
BACKTEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Sell and Hold"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_s&h_test'
TEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Sell and Hold"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = 'eth_s&h_test'
# ETH_TEST_PARAM['network'] = ''
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_tfma_training'
NON_AI_TRAINING_PARAM['network'] = ''
simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = "btc_tfma_validation"
VALIDATION_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = "btc_tfma_backtest"
BACKTEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Trend Following Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = "btc_tfma_test"
TEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Trend Following Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = "eth_tfma_test"
# ETH_TEST_PARAM['network'] = ''
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
NON_AI_TRAINING_PARAM['name'] = 'btc_mrma_training'
NON_AI_TRAINING_PARAM['network'] = ''
simulator.nonAitrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
VALIDATION_PARAM['name'] = "btc_mrma_validation"
VALIDATION_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, VALIDATION_PARAM)
print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = "btc_mrma_backtest"
BACKTEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, BACKTEST_PARAM)
print()

# %%
strategy = "Mean Reversion Moving Averages"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = "btc_mrma_test"
TEST_PARAM['network'] = ''
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, TEST_PARAM)
print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Ethereum"
# ETH_TEST_PARAM['name'] = "eth_mrma_test"
# ETH_TEST_PARAM['network'] = ''
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, ETH_TEST_PARAM)
# print()
