# %%
# import the files
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()

# %%
# strategy, cryptocurrency and network supported
# strategy in {
#     'Buy and Hold',
#     'Sell and Hold',
#     'Trend Following Moving Averages',
#     'Mean Reversion Moving Averages',
#     'TDQN'
# }
# cryptocurrency in {'Bitcoin'}
# network in {"DQN", "LSTM", "ConvDuelingDQN"}

# %%
# # EDA
# cryptocurrency = "Bitcoin"
# simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')

# %%
# # randomized search optimization 
# percentageCosts = [0, 0.1, 0.2]
# transactionCosts = percentageCosts[1]/100
# stateLength = 30
# OPTIMIZATION_TRAINING_PARAM = {
#     'money': 100000,
#     'percentageCosts': percentageCosts,
#     'transactionCosts': transactionCosts,
#     'name': 'training',
#     'network': '',
#     # Parameters related to the DQN algorithm
#     'stateLength': stateLength,
#     'numberOfEpisodes': 1,
#     'targetNetworkUpdate': 1000,
#     'learningUpdatePeriod': 1,
#     # Default parameters related to the Experience Replay mechanism
#     'capacity': 100000,
#     'batchSize': 32,
#     'experiencesRequired': 1000,
#     # Default parameters related to the Deep Neural Network
#     'numberOfNeurons': 512,
#     # Default parameters related to the Epsilon-Greedy exploration technique
#     'epsilonStart': 1.0,
#     'epsilonEnd': 0.01,
#     # Default parameters regarding the sticky actions RL generalization technique
#     # Default parameters related to preprocessing
#     'filterOrder': 5,
#     # Default paramters related to the clipping of both the gradient and the RL rewards
#     'gradientClipping': 1,
#     'rewardClipping': 1,
# }
# OPTIMIZATION_VALIDATION_PARAM = {
#     'money': 100000,
#     'stateLength': stateLength,
#     'transactionCosts': transactionCosts,
#     'name': 'validation',
#     'network': '',
# }
# # hyperparameters will be selected randomly from the range specified below
# OPTIMIZATION_HYPERPARAM = {
#     'gamma': [.1, .9],
#     'learningRate': [.0001, .005],
#     'dropout': [.1, .9],
#     'epsilonDecay': [5000,500000],
#     'alpha': [.1, .9],
#     'L2Factor': [.1, .000001],
# }

# strategy = "TDQN"
# trainCryptocurrency = "Bitcoin"
# OPTIMIZATION_TRAINING_PARAM['network'] = 'ConvDuelingDQN'
# OPTIMIZATION_TRAINING_PARAM['name'] = 'btc_tdqn_ConvDuelingDQN_training'
# OPTIMIZATION_VALIDATION_PARAM['network'] = 'ConvDuelingDQN'
# OPTIMIZATION_VALIDATION_PARAM['name'] = 'btc_tdqn_ConvDuelingDQN_validation'
# simulator.randomizedSearchOptimization(strategy, trainCryptocurrency, OPTIMIZATION_TRAINING_PARAM, OPTIMIZATION_VALIDATION_PARAM, OPTIMIZATION_HYPERPARAM, 3)
# print()

# %%
# set parameters after optimization
percentageCosts = [0, 0.1, 0.2]
transactionCosts = percentageCosts[1]/100
stateLength = 30
AI_TRAINING_PARAM = {
    'money': 100000,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    'name': 'training',
    'network': '',
    # Parameters related to the DQN algorithm
    'stateLength': stateLength,
    'numberOfEpisodes': 50,
    'gamma': 0.4,
    'learningRate': 0.0001,
    'targetNetworkUpdate': 1000,
    'learningUpdatePeriod': 1,
    # Default parameters related to the Experience Replay mechanism
    'capacity': 100000,
    'batchSize': 32,
    'experiencesRequired': 1000,
    # Default parameters related to the Deep Neural Network
    'numberOfNeurons': 512,
    'dropout': 0.2,
    # Default parameters related to the Epsilon-Greedy exploration technique
    'epsilonStart': 1.0,
    'epsilonEnd': 0.01,
    'epsilonDecay': 10000,
    # Default parameters regarding the sticky actions RL generalization technique
    'alpha': 0.1,
    # Default parameters related to preprocessing
    'filterOrder': 5,
    # Default paramters related to the clipping of both the gradient and the RL rewards
    'gradientClipping': 1,
    'rewardClipping': 1,
    # Default parameter related to the L2 Regularization 
    'L2Factor': 0.000001,
    # Default parameter for animation
    'animation': False
}

NON_AI_TRAINING_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2019-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'percentageCosts': percentageCosts,
    'transactionCosts': transactionCosts,
    'name': 'training',
    'network': ''
}

VALIDATION_PARAM = {
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'validation',
    'network': '',
}

BACKTEST_PARAM = {
    'startingDate': '2014-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'backtest',
    'network': '',
}

TEST_PARAM = {
    'startingDate': '2019-01-01',
    'endingDate': '2021-01-01',
    'money': 100000,
    'stateLength': stateLength,
    'transactionCosts': transactionCosts,
    'name': 'test',
    'network': '',
}

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
AI_TRAINING_PARAM['network'] = 'DQN'
AI_TRAINING_PARAM['name'] = 'btc_tdqn_DQN_training'
VALIDATION_PARAM['network'] = 'DQN'
VALIDATION_PARAM['name'] = 'btc_tdqn_DQN_validation'
simulator.aiTrainWithCrossValidation(strategy, trainCryptocurrency, AI_TRAINING_PARAM, VALIDATION_PARAM)
print()
# Out:
# Training1
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [03:49<00:00,  4.59s/it]
# ╒═══════════════════════════╤═════════╕
# │   Performance Indicator   │  TDQN   │
# ╞═══════════════════════════╪═════════╡
# │    Profit & Loss (P&L)    │  27472  │
# ├───────────────────────────┼─────────┤
# │     Annualized Return     │ 31.15%  │
# ├───────────────────────────┼─────────┤
# │   Annualized Volatility   │ 30.62%  │
# ├───────────────────────────┼─────────┤
# │       Sharpe Ratio        │  0.700  │
# ├───────────────────────────┼─────────┤
# │       Sortino Ratio       │  0.894  │
# ├───────────────────────────┼─────────┤
# │     Maximum Drawdown      │ 24.64%  │
# ├───────────────────────────┼─────────┤
# │ Maximum Drawdown Duration │ 54 days │
# ├───────────────────────────┼─────────┤
# │       Profitability       │ 33.33%  │
# ├───────────────────────────┼─────────┤
# │ Ratio Average Profit/Loss │  3.275  │
# ├───────────────────────────┼─────────┤
# │         Skewness          │  0.097  │
# ╘═══════════════════════════╧═════════╛
# Validation1
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ -101751  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 102.19%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -0.577  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.315  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 101.54%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 294 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  56.76%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.264   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -10.500  │
# ╘═══════════════════════════╧══════════╛
# Training2
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [06:58<00:00,  8.37s/it]
# ╒═══════════════════════════╤═════════╕
# │   Performance Indicator   │  TDQN   │
# ╞═══════════════════════════╪═════════╡
# │    Profit & Loss (P&L)    │  46275  │
# ├───────────────────────────┼─────────┤
# │     Annualized Return     │ 20.38%  │
# ├───────────────────────────┼─────────┤
# │   Annualized Volatility   │ 21.68%  │
# ├───────────────────────────┼─────────┤
# │       Sharpe Ratio        │  0.714  │
# ├───────────────────────────┼─────────┤
# │       Sortino Ratio       │  0.891  │
# ├───────────────────────────┼─────────┤
# │     Maximum Drawdown      │ 24.64%  │
# ├───────────────────────────┼─────────┤
# │ Maximum Drawdown Duration │ 54 days │
# ├───────────────────────────┼─────────┤
# │       Profitability       │ 100.00% │
# ├───────────────────────────┼─────────┤
# │ Ratio Average Profit/Loss │   inf   │
# ├───────────────────────────┼─────────┤
# │         Skewness          │  0.257  │
# ╘═══════════════════════════╧═════════╛
# Validation2
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │ -100303  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 124.15%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -0.869  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.454  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 100.49%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 357 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  0.00%   │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -9.519  │
# ╘═══════════════════════════╧══════════╛
# Training3
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [11:13<00:00, 13.48s/it]
# ╒═══════════════════════════╤═══════════╕
# │   Performance Indicator   │   TDQN    │
# ╞═══════════════════════════╪═══════════╡
# │    Profit & Loss (P&L)    │  -100032  │
# ├───────────────────────────┼───────────┤
# │     Annualized Return     │ -100.00%  │
# ├───────────────────────────┼───────────┤
# │   Annualized Volatility   │  153.62%  │
# ├───────────────────────────┼───────────┤
# │       Sharpe Ratio        │  -0.595   │
# ├───────────────────────────┼───────────┤
# │       Sortino Ratio       │  -0.551   │
# ├───────────────────────────┼───────────┤
# │     Maximum Drawdown      │  100.03%  │
# ├───────────────────────────┼───────────┤
# │ Maximum Drawdown Duration │ 1060 days │
# ├───────────────────────────┼───────────┤
# │       Profitability       │  46.67%   │
# ├───────────────────────────┼───────────┤
# │ Ratio Average Profit/Loss │   0.005   │
# ├───────────────────────────┼───────────┤
# │         Skewness          │  -3.761   │
# ╘═══════════════════════════╧═══════════╛
# Validation3
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -99676  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 135.35%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.160  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.784  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 102.19%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 156 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  41.38%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.337   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -11.604  │
# ╘═══════════════════════════╧══════════╛
# Training4
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [14:27<00:00, 17.35s/it]
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -99969  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ 137.56%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 1369.94% │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.388   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  4.431   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 874 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  83.87%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  36.668  │
# ╘═══════════════════════════╧══════════╛
# Validation4
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -35391  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -15.58%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  62.21%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -0.172  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.226  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  67.45%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 224 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  42.22%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  1.126   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -0.072  │
# ╘═══════════════════════════╧══════════╛
# Training5
#   0%|          | 0/50 [00:00<?, ?it/s]
# Training progression (hardware selected => cuda:0):
# 100%|██████████| 50/50 [18:18<00:00, 21.98s/it]
# C:\Users\Victor\Documents\school\yr 2 sem 2\COMP3359 AI applications\COMP3359_GP15_Deep_Reinforcement_Learning_in_Cryptocurrency_Algorithmic_Trading-main\tdqn_final\tradingEnv.py:303: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=(10, 8))
# ╒═══════════════════════════╤═══════════╕
# │   Performance Indicator   │   TDQN    │
# ╞═══════════════════════════╪═══════════╡
# │    Profit & Loss (P&L)    │  -95931   │
# ├───────────────────────────┼───────────┤
# │     Annualized Return     │ -100.00%  │
# ├───────────────────────────┼───────────┤
# │   Annualized Volatility   │  60.40%   │
# ├───────────────────────────┼───────────┤
# │       Sharpe Ratio        │  -0.420   │
# ├───────────────────────────┼───────────┤
# │       Sortino Ratio       │  -0.502   │
# ├───────────────────────────┼───────────┤
# │     Maximum Drawdown      │  97.37%   │
# ├───────────────────────────┼───────────┤
# │ Maximum Drawdown Duration │ 1534 days │
# ├───────────────────────────┼───────────┤
# │       Profitability       │  46.92%   │
# ├───────────────────────────┼───────────┤
# │ Ratio Average Profit/Loss │   0.923   │
# ├───────────────────────────┼───────────┤
# │         Skewness          │  -0.723   │
# ╘═══════════════════════════╧═══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
TEST_PARAM['name'] = 'btc_tdqn_DQN_test'
TEST_PARAM['network'] = 'DQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, TEST_PARAM)
print()
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -99947  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 120.99%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.132  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.955  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  99.99%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 511 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  54.55%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.700   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -4.901  │
# ╘═══════════════════════════╧══════════╛

# %%
strategy = "TDQN"
trainCryptocurrency = "Bitcoin"
testCryptocurrency = "Bitcoin"
BACKTEST_PARAM['name'] = 'btc_tdqn_DuelingDQN_backtest'
BACKTEST_PARAM['network'] = 'DuelingDQN'
simulator.test(strategy, trainCryptocurrency, testCryptocurrency, AI_TRAINING_PARAM, BACKTEST_PARAM)
print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# NON_AI_TRAINING_PARAM['name'] = 'btc_mrma_training'
# simulator.nonAiTrain(strategy, trainCryptocurrency, NON_AI_TRAINING_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# BACKTEST_PARAM['name'] = 'btc_mrma_backtest'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, NON_AI_TRAINING_PARAM, BACKTEST_PARAM)
# print()

# %%
# strategy = "Mean Reversion Moving Averages"
# trainCryptocurrency = "Bitcoin"
# testCryptocurrency = "Bitcoin"
# TEST_PARAM['name'] = 'btc_mrma_test'
# simulator.test(strategy, trainCryptocurrency, testCryptocurrency, NON_AI_TRAINING_PARAM, TEST_PARAM)
# print()
