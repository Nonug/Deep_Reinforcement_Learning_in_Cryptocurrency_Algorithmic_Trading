# %%
from tradingSimulator import TradingSimulator
simulator = TradingSimulator()
import testStrategy

# %%
cryptocurrency = "Bitcoin"
simulator.exploratoryDataAnalysis(cryptocurrency, '2014-01-01', '2021-01-01')
# Out:
# Number of empty elements:
# Open     0
# High     0
# Low      0
# Close    0
# s2f      0
# dtype: int64
# Number of duplicates:
# 0

# %%
classicalStrats = {
    'Buy and Hold' : 'b&h',
    'Sell and Hold' : 's&h',
    'Trend Following Moving Averages' : 'tfma'
}
AI = ['DQN', 'LSTM', 'ConvDuelingDQN']

# %%
strat = 'Buy and Hold'
testStrategy.test(strat)
# Out:
# No training is required as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# No training results are available as the simple Buy and Hold trading strategy does not involve any tunable parameters.
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   B&H    │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  364249  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  31.41%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  61.81%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  0.652   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  0.855   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  83.46%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 364 days │
# ├───────────────────────────┼──────────┤
# ...

# %% [markdown]
# ## DQN from our interim prototype

# %%
testStrategy.testAI("DQN",name = "prototype")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  714784  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  89.65%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  57.35%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.561   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.891   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  62.09%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 260 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -1.073  │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ## DQN with cross-validation

# %%
testStrategy.testAI("DQN")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -98717  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 110.67%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.261  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.408  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 105.16%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 93 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  92.86%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -16.431  │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ## ConvDuelingDQN with cross-validation, dropout layer and optimized

# %%
testStrategy.testAI("ConvDuelingDQN", name = "optimized")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  714784  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │  89.65%  │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │  57.35%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  1.561   │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  1.891   │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │  62.09%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 260 days │
# ├───────────────────────────┼──────────┤
# │       Profitability       │ 100.00%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │   inf    │
# ├───────────────────────────┼──────────┤
# │         Skewness          │  -1.073  │
# ╘═══════════════════════════╧══════════╛

# %% [markdown]
# ## LSTM with cross-validation, normalized layers

# %%
testStrategy.testAI("LSTM")
# Out:
# ╒═══════════════════════════╤══════════╕
# │   Performance Indicator   │   TDQN   │
# ╞═══════════════════════════╪══════════╡
# │    Profit & Loss (P&L)    │  -98717  │
# ├───────────────────────────┼──────────┤
# │     Annualized Return     │ -100.00% │
# ├───────────────────────────┼──────────┤
# │   Annualized Volatility   │ 110.67%  │
# ├───────────────────────────┼──────────┤
# │       Sharpe Ratio        │  -1.261  │
# ├───────────────────────────┼──────────┤
# │       Sortino Ratio       │  -0.408  │
# ├───────────────────────────┼──────────┤
# │     Maximum Drawdown      │ 105.16%  │
# ├───────────────────────────┼──────────┤
# │ Maximum Drawdown Duration │ 93 days  │
# ├───────────────────────────┼──────────┤
# │       Profitability       │  93.33%  │
# ├───────────────────────────┼──────────┤
# │ Ratio Average Profit/Loss │  0.000   │
# ├───────────────────────────┼──────────┤
# │         Skewness          │ -16.431  │
# ╘═══════════════════════════╧══════════╛
